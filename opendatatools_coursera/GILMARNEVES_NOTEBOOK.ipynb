# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **GILMAR NEVES**
#
# CHEMICAL ENGINEER

# %% [markdown]
# *I AM INTERESTED IN DATA SCIENCE BECAUSE I WANNA CHANGE MY CAREER. I AM WILLING TO LEAVE CHEMICAL ENGINEERING FOR A ENTRY LEVEL JOB AS LONG AS I GET TO WORK WITH CODING AND DATA.*
#
# PS: SORRY ABOUT THE LACK OF FORMATATION OF THIS NOTEBOOK. I AM HAVING TROUBLES WITH THE IBM CLOUD.

# %% [markdown]
# ### THE CODE BELOW IS A SIMPLE PYTHON 3 EXAMPLE. IT PRINTS 10 TIMES A SENTENCE PRE-DEFINED BY ME. I WANNA SHOW YOU, THOSE WHO DOES'T CODE, A QUITE SIMPLE USE OF 'FOR LOOPS'

# %%
for i in range(10):
    print ("This is print number" + str(i+1) + " in a for loop!")
# Out:
# This is print number1 in a for loop!
# This is print number2 in a for loop!
# This is print number3 in a for loop!
# This is print number4 in a for loop!
# This is print number5 in a for loop!
# This is print number6 in a for loop!
# This is print number7 in a for loop!
# This is print number8 in a for loop!
# This is print number9 in a for loop!
# This is print number10 in a for loop!

# %% [markdown]
# This code was generated using ~~Python 2~~ Python 3 syntax
#
# It shows:
#
#   * print statement
#   * for loop
#   * range method
#
# ![image.png](attachment:image.png)
